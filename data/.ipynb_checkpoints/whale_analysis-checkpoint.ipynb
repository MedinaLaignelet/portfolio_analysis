# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
csvpath = Path("whale_returns.csv")

# %%
whale_returns = pd.read_csv(csvpath)
whale_returns.head()

# Sort data by `Date` in ascending order
whale_returns = whale_returns.sort_values("Date", ascending=True)
whale_returns.head()

whale_returns.set_index(pd.to_datetime(whale_returns['Date'], infer_datetime_format=True), inplace=True)
whale_returns.head()

# Drop the extra date column
whale_returns.drop(columns=['Date'], inplace=True)
whale_returns.head()
# Out:
# C:\Users\medin\AppData\Local\Temp\ipykernel_8272\100833376.py:8: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   whale_returns.set_index(pd.to_datetime(whale_returns['Date'], infer_datetime_format=True), inplace=True)
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# ...

# %%
# Count nulls
whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_returns = whale_returns.dropna().copy()
whale_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %%
whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
csvpath = Path("algo_returns.csv")

# %%
algo_returns = pd.read_csv(csvpath)
algo_returns.head()

# Sort data by `Date` in ascending order
algo_returns = algo_returns.sort_values("Date", ascending=True)
algo_returns.head()

algo_returns.set_index(pd.to_datetime(algo_returns['Date'], infer_datetime_format=True), inplace=True)
algo_returns.head()

# Drop the extra date column
algo_returns.drop(columns=['Date'], inplace=True)
algo_returns.head()
# Out:
# C:\Users\medin\AppData\Local\Temp\ipykernel_8272\4284911037.py:8: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   algo_returns.set_index(pd.to_datetime(algo_returns['Date'], infer_datetime_format=True), inplace=True)
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
#Checking nulls
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
csvpath = Path("sp500_history.csv")

# %%
sp500_history = pd.read_csv(csvpath)
sp500_history.head()
# Out:
#         Date     Close
# 0  23-Apr-19  $2933.68
# 1  22-Apr-19  $2907.97
# 2  18-Apr-19  $2905.03
# 3  17-Apr-19  $2900.45
# 4  16-Apr-19  $2907.06

# %%
# Check Data Types
sp500_history.dtypes
# Out:
# Date     object
# Close    object
# dtype: object

# %%
# Fix Data Types
sp500_history["Close"] = sp500_history["Close"].str.replace("$", "")
sp500_history["Close"]
# Out:
# 0       2933.68
# 1       2907.97
# 2       2905.03
# 3       2900.45
# 4       2907.06
#          ...
# 1644    1460.93
# 1645    1461.40
# 1646    1450.99
# 1647    1445.75
# 1648    1444.49
# Name: Close, Length: 1649, dtype: object

# %%
sp500_history["Close"] = sp500_history["Close"].astype("float")

# %%
sp500_history.dtypes
# Out:
# Date      object
# Close    float64
# dtype: object

# %%
# Calculate Daily Returns
import pandas as pd
# %matplotlib inline

# %%
# Set the date as the index to the DataFrame
sp500_history.set_index(pd.to_datetime(sp500_history['Date'], infer_datetime_format=True), inplace=True)
sp500_history.head()
# Out:
# C:\Users\medin\AppData\Local\Temp\ipykernel_8272\825180050.py:2: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   sp500_history.set_index(pd.to_datetime(sp500_history['Date'], infer_datetime_format=True), inplace=True)
# C:\Users\medin\AppData\Local\Temp\ipykernel_8272\825180050.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sp500_history.set_index(pd.to_datetime(sp500_history['Date'], infer_datetime_format=True), inplace=True)
#                  Date    Close
# Date
# 2019-04-23  23-Apr-19  2933.68
# 2019-04-22  22-Apr-19  2907.97
# 2019-04-18  18-Apr-19  2905.03
# 2019-04-17  17-Apr-19  2900.45
# ...

# %%
# Drop the extra date column
sp500_history.drop(columns=['Date'], inplace=True)
sp500_history.head()
# Out:
#               Close
# Date
# 2019-04-23  2933.68
# 2019-04-22  2907.97
# 2019-04-18  2905.03
# 2019-04-17  2900.45
# 2019-04-16  2907.06

# %%
# Calculate the daily return using the 'pct_change()' function
daily_returns_sp500 = sp500_history.pct_change()
daily_returns_sp500.head()
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279

# %%
# Drop nulls
daily_returns_sp500 = daily_returns_sp500.dropna().copy()
daily_returns_sp500
# Out:
#                Close
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509
# ...              ...
# 2012-10-05  0.003469
# 2012-10-04  0.000322
# 2012-10-03 -0.007123
# 2012-10-02 -0.003611
# 2012-10-01 -0.000872
#
# [1648 rows x 1 columns]

# %%
#checking nulls:
daily_returns_sp500.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
# Rename `Close` Column to be specific to this portfolio.
daily_returns_sp500 = daily_returns_sp500.rename(columns={
    "Close": "SP500"
   })

daily_returns_sp500.head()
# Out:
#                SP500
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
joined_data_cols = pd.concat([whale_returns, algo_returns, daily_returns_sp500], axis='columns', join='inner')
joined_data_cols.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2     SP500
# Date
# 2015-03-03 -0.000949  0.004408
# 2015-03-04  0.002416 -0.001195
# 2015-03-05  0.004323  0.014378
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
#Importing pandas
import pandas as pd
# %matplotlib inline

# %%
# Whale return data already presented as daily return. Plot only:
whale_returns.plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Date'>

# %%
 #Algo Daily retun plot
algo_returns.plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Date'>

# %%
#SP500 portfolio Daily retun plot
daily_returns_sp500.plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
# whale_returns, algo_returns, daily_returns_sp500

#Whale Returns cumulative returns
cumulative_returns_whale = (1 + whale_returns).cumprod()
cumulative_returns_whale.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                   0.998734            0.995019
# 2015-03-04                   1.000962            0.998245
# 2015-03-05                   1.004981            1.002314
# 2015-03-06                   0.997037            0.998731
# 2015-03-09                   0.997617            1.002951
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                     0.999504                0.993431
# 2015-03-04                     0.996972                0.997617
# 2015-03-05                     0.999319                1.004327
# 2015-03-06                     0.990844                0.991172
# 2015-03-09                     0.996633                0.989534

# %%
#Algo returns cumulative returns
cumulative_returns_algo = (1 + algo_returns).cumprod()
cumulative_returns_algo.head()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  1.004062  1.013285
# 2014-06-06  1.005927  1.021679
# 2014-06-09  1.000885  1.027470
# 2014-06-10  1.005295  1.026714
# 2014-06-11  1.010081  1.022852

# %%
#SP500 cumulative returns
cumulative_returns_sp500 = (1 + daily_returns_sp500).cumprod()
cumulative_returns_sp500.head()
# Out:
#                SP500
# Date
# 2019-04-22  0.991236
# 2019-04-18  0.990234
# 2019-04-17  0.988673
# 2019-04-16  0.990926
# 2019-04-15  0.990422

# %%
# Plot cumulative returns

cumulative_returns_whale.plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Date'>

# %%
# Plot cumulative returns

cumulative_returns_algo.plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Date'>

# %%
# Plot cumulative returns

cumulative_returns_sp500.plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
    #whale_returns portfolio, 
whale_returns.plot.box()
# Out:
# <Axes: >

# %%
    # algo_retunr portfolio, 
algo_returns.plot.box()
# Out:
# <Axes: >

# %%
    #sp500 retun portfolio
daily_returns_sp500.plot.box()
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
# Daily Standard Deviations Whale Portfolio
daily_std_whale = whale_returns.std()
daily_std_whale
# Out:
# SOROS FUND MANAGEMENT LLC      0.007842
# PAULSON & CO.INC.              0.006977
# TIGER GLOBAL MANAGEMENT LLC    0.010824
# BERKSHIRE HATHAWAY INC         0.012831
# dtype: float64

# %%
# Daily Standard Deviations algo portfolio
daily_std_algo = algo_returns.std()
daily_std_algo
# Out:
# Algo 1    0.007988
# Algo 2    0.008466
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
# Daily Standard Deviations Sp500
daily_std_sp500 = daily_returns_sp500.std()
daily_std_sp500
# Out:
# SP500    0.008135
# dtype: float64

# %%
# Determine which portfolios are riskier than the S&P 500
daily_std_whale.sort_values(ascending=False) 
daily_std_whale.head()
# Out:
# SOROS FUND MANAGEMENT LLC      0.007842
# PAULSON & CO.INC.              0.006977
# TIGER GLOBAL MANAGEMENT LLC    0.010824
# BERKSHIRE HATHAWAY INC         0.012831
# dtype: float64

# %%
daily_std_algo.sort_values(ascending=False) 
daily_std_algo.head()
# Out:
# Algo 1    0.007988
# Algo 2    0.008466
# dtype: float64

# %%
#Portfolios riskier than sp500: TIGER GLOBAL MANAGEMENT LLC    0.010824 and BERKSHIRE HATHAWAY INC  0.012831 and Algo 2    0.008466

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
import pandas as pd
from pathlib import Path
import seaborn as sns

# %matplotlib inline

# %%
# Calculate the annualized standard deviation (252 trading days)
    #whale Portfolio
annualized_std_whale = daily_std_whale*np.sqrt(252)
annualized_std_whale
# Out:
# array([ 8.02254922,  5.78279009, -0.51440437, ..., -3.36362164,
#        11.95428327,  2.13765719])

# %%
    #algo Portfolio
annualized_std_algo = daily_std_algo*np.sqrt(252)
annualized_std_algo
# Out:
# array([-31.27561648,   2.68844546,  -7.02909004, ...,  -4.7623972 ,
#         33.62660472,  25.87715308])

# %%
    #SP500
annualized_std_sp500 = daily_std_sp500*np.sqrt(252)
annualized_std_sp500
# Out:
# array([ -2.40903629,  22.85734362, -19.43334255, ...,  -1.25872529,
#          7.47318773,  -5.65964131])

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
    #whale portfolio
whale_rollstd_21 = whale_returns.rolling(window=21).std()
whale_rollstd_21
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                        NaN                 NaN
# 2015-03-04                        NaN                 NaN
# 2015-03-05                        NaN                 NaN
# 2015-03-06                        NaN                 NaN
# 2015-03-09                        NaN                 NaN
# ...                               ...                 ...
# 2019-04-25                   0.004145            0.005572
# 2019-04-26                   0.004117            0.005649
# 2019-04-29                   0.004123            0.005374
# 2019-04-30                   0.004199            0.005408
# 2019-05-01                   0.004271            0.005009
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                          NaN                     NaN
# 2015-03-04                          NaN                     NaN
# ...

# %%
    # Plot the rolling standard deviation Whale Portfolio
    
    ax = whale_rollstd_21.plot(figsize=(15,5))

# %%
     #Rolling STD 21 day Algo Portfolio
algo_rollstd_21 = algo_returns.rolling(window=21).std()
algo_rollstd_21
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05       NaN       NaN
# 2014-06-06       NaN       NaN
# 2014-06-09       NaN       NaN
# 2014-06-10       NaN       NaN
# 2014-06-11       NaN       NaN
# ...              ...       ...
# 2019-04-25  0.005801  0.005764
# 2019-04-26  0.005562  0.005700
# 2019-04-29  0.005251  0.005622
# 2019-04-30  0.005294  0.005600
# 2019-05-01  0.004972  0.005686
#
# [1235 rows x 2 columns]

# %%
    # Plot the rolling standard deviation Algo Portfolio
    
    ax = algo_rollstd_21.plot(figsize=(15,5))

# %%
    #Rolling  STD 21 day SP500
sp500_rollstd_21 = daily_returns_sp500.rolling(window=21).std()
sp500_rollstd_21
# Out:
#                SP500
# Date
# 2019-04-22       NaN
# 2019-04-18       NaN
# 2019-04-17       NaN
# 2019-04-16       NaN
# 2019-04-15       NaN
# ...              ...
# 2012-10-05  0.009007
# 2012-10-04  0.007462
# 2012-10-03  0.007424
# 2012-10-02  0.007463
# 2012-10-01  0.007218
#
# [1648 rows x 1 columns]

# %%
# Plot the rolling standard deviation Sp500
ax = sp500_rollstd_21.plot(figsize=(15,5))

# %%
    # Plot the rolling standard deviation all portfolios 
      
    # Set figure of the daily closing prices of NFLX
ax = sp500_rollstd_21.plot(figsize=(15,5))

# Overlay SMA20, SMA50, and SMA100 on the same figure
whale_rollstd_21.plot(ax=ax)
algo_rollstd_21.plot(ax=ax)


# Set the legend of the figure
ax.legend(["SP500 Portfolio Rolling STD 21 days", "Whale Portfolio Rolling STD 21 days", "Algo Portfolio Rolling STD 21 days"]);

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation_join = joined_data_cols.corr()
correlation_join
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699823
# PAULSON & CO.INC.                             0.699823            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561040            0.434308
# BERKSHIRE HATHAWAY INC                        0.754157            0.545451
# Algo 1                                        0.320901            0.268631
# Algo 2                                        0.826730            0.678085
# SP500                                         0.000574            0.013549
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561040
# PAULSON & CO.INC.                               0.434308
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424125
# Algo 1                                          0.164114
# ...

# %%
#Plot the correlation
sns.heatmap(correlation_join, vmin=-1, vmax=1, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# Calculate covariance of a single portfolio (Algo Portfolio)
Algo1_covariance = joined_data_cols['Algo 1'].cov(joined_data_cols['SP500'])
Algo2_covariance = joined_data_cols['Algo 2'].cov(joined_data_cols['SP500'])
Algo1_covariance
Algo2_covariance
# Out:
# -1.5699865363012443e-07

# %%
# Calculate variance of S&P 500
variance_sp500 = joined_data_cols['SP500'].var()
variance_sp500
# Out:
# 7.373467552840441e-05

# %%
# Computing beta
Algo1_beta = Algo1_covariance / variance_sp500
Algo2_beta = Algo2_covariance / variance_sp500

print(f"Algo1: {Algo1_beta} | : Algo2:{Algo2_beta} ")
# Out:
# Algo1: -0.03014921454233756 | : Algo2:-0.002129237736587648

# %%
# Plot beta trend 60 days

# Calculate 60-day rolling covariance of Algo1 and Algo 2 vs. S&P 500 and plot the data
rolling_algo1_covariance = joined_data_cols['Algo 1'].rolling(window=60).cov(joined_data_cols['SP500'])
rolling_algo2_covariance = joined_data_cols['Algo 2'].rolling(window=60).cov(joined_data_cols['SP500'])


# Calculate 60-day rolling variance of S&P 500
rolling_variance_sp500 = joined_data_cols['SP500'].rolling(window=30).var()

# Calculate 60-day rolling beta of Algo Portfolio and plot the data
rolling_algo1_beta = rolling_algo1_covariance / rolling_variance_sp500
rolling_algo2_beta = rolling_algo2_covariance / rolling_variance_sp500

ax = rolling_algo1_beta.plot(figsize=(20, 10), title='Algo Portfolio Beta Trend 60 day rolling')
rolling_algo2_beta.plot(ax=ax)


# Set the legend of the figure
ax.legend(["Algo 1 Portafolio", "Algo 2 Portafolio"])

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
joined_data_cols.ewm(halflife=21).std().plot(figsize=(15,5));

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = (joined_data_cols.mean() * 252) / (joined_data_cols.std() * np.sqrt(252))
sharpe_ratios.sort_values(inplace=True)
sharpe_ratios
# Out:
# SP500                         -0.518582
# PAULSON & CO.INC.             -0.491422
# TIGER GLOBAL MANAGEMENT LLC   -0.130186
# SOROS FUND MANAGEMENT LLC      0.342894
# Algo 2                         0.484334
# BERKSHIRE HATHAWAY INC         0.606743
# Algo 1                         1.369589
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# The S&P500 Index outperforms both the Algorithmic and Whale Portfolios as its sharpe ratio is lower (-0.518582) than the other Portfolios.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Import libraries and dependencies
import numpy as np
import pandas as pd
from pathlib import Path
import seaborn as sns
# %matplotlib inline

# %%
# Reading data from 1st stock
# Set the file paths
csvpath= Path("aapl_historical.csv")

# %%
aapl_data = pd.read_csv(csvpath)
aapl_data.head()

# Sort data by `Date` in ascending order
aapl_data = aapl_data.sort_values("Trade DATE", ascending=True)
aapl_data.head()

# Read the CSVs and set the `date` column as a datetime index to the DataFrame
aapl_data.set_index(pd.to_datetime(aapl_data['Trade DATE'], infer_datetime_format=True), inplace=True)
aapl_data.head()

# Drop the extra date column
aapl_data.drop(columns=['Trade DATE'], inplace=True)
aapl_data.head()
# Out:
# C:\Users\medin\AppData\Local\Temp\ipykernel_8272\188970662.py:9: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   aapl_data.set_index(pd.to_datetime(aapl_data['Trade DATE'], infer_datetime_format=True), inplace=True)
#            Symbol    NOCP
# Trade DATE
# 2019-01-10   AAPL  153.80
# 2019-01-11   AAPL  152.29
# 2019-01-14   AAPL  150.00
# 2019-01-15   AAPL  153.07
# 2019-01-16   AAPL  154.94

# %%
# Reading data from 2nd stock
csvpath = Path("cost_historical.csv")

# %%
cost_data = pd.read_csv(csvpath)
cost_data.head()

# Sort data by `Date` in ascending order
cost_data = cost_data.sort_values("Trade DATE", ascending=True)
cost_data.head()

# Read the CSVs and set the `date` column as a datetime index to the DataFrame
cost_data.set_index(pd.to_datetime(cost_data['Trade DATE'], infer_datetime_format=True), inplace=True)
cost_data.head()

# Drop the extra date column
cost_data.drop(columns=['Trade DATE'], inplace=True)
cost_data.head()
# Out:
# C:\Users\medin\AppData\Local\Temp\ipykernel_8272\9383837.py:9: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   cost_data.set_index(pd.to_datetime(cost_data['Trade DATE'], infer_datetime_format=True), inplace=True)
#            Symbol    NOCP
# Trade DATE
# 2019-01-10   COST  210.64
# 2019-01-11   COST  210.51
# 2019-01-14   COST  209.00
# 2019-01-15   COST  211.03
# 2019-01-16   COST  210.18

# %%
# Reading data from 3rd stock
csvpath = Path("goog_historical.csv")

# %%
goog_data = pd.read_csv(csvpath)
goog_data.head()

# Sort data by `Date` in ascending order
goog_data = goog_data.sort_values("Trade DATE", ascending=True)
goog_data.head()

# Read the CSVs and set the `date` column as a datetime index to the DataFrame
goog_data.set_index(pd.to_datetime(goog_data['Trade DATE'], infer_datetime_format=True), inplace=True)
goog_data.head()

# Drop the extra date column
goog_data.drop(columns=['Trade DATE'], inplace=True)
goog_data.head()
# Out:
# C:\Users\medin\AppData\Local\Temp\ipykernel_8272\1400989246.py:9: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   goog_data.set_index(pd.to_datetime(goog_data['Trade DATE'], infer_datetime_format=True), inplace=True)
#            Symbol     NOCP
# Trade DATE
# 2019-01-10   GOOG  1070.33
# 2019-01-11   GOOG  1057.19
# 2019-01-14   GOOG  1044.69
# 2019-01-15   GOOG  1077.15
# 2019-01-16   GOOG  1080.97

# %%
# Combine all stocks in a single DataFrame
# Join your returns DataFrame to the original returns DataFrame
joined_stock_data = pd.concat([aapl_data, cost_data, goog_data], axis='columns', join='inner')
joined_stock_data.head()
# Out:
#            Symbol    NOCP Symbol    NOCP Symbol     NOCP
# Trade DATE
# 2019-01-10   AAPL  153.80   COST  210.64   GOOG  1070.33
# 2019-01-11   AAPL  152.29   COST  210.51   GOOG  1057.19
# 2019-01-14   AAPL  150.00   COST  209.00   GOOG  1044.69
# 2019-01-15   AAPL  153.07   COST  211.03   GOOG  1077.15
# 2019-01-16   AAPL  154.94   COST  210.18   GOOG  1080.97

# %%
# Reset Date index
joined_stock_data.sort_index(inplace=True)

# %%
# Reorganize portfolio data by having a column per symbol
joined_stock_data.columns
# Out:
# Index(['Symbol', 'NOCP', 'Symbol', 'NOCP', 'Symbol', 'NOCP'], dtype='object')

# %%
# Rewrite the column names
columns = ["Symbol aapl", "AAPL", "Symbol cost", "COST", "Symbol goog", "GOOG"]
joined_stock_data.columns = columns
joined_stock_data.head()
# Out:
#            Symbol aapl    AAPL Symbol cost    COST Symbol goog     GOOG
# Trade DATE
# 2018-05-11        AAPL  188.59        COST  195.76        GOOG  1098.26
# 2018-05-14        AAPL  188.15        COST  195.88        GOOG  1100.20
# 2018-05-15        AAPL  186.44        COST  195.48        GOOG  1079.23
# 2018-05-16        AAPL  188.18        COST  198.71        GOOG  1081.77
# 2018-05-17        AAPL  186.99        COST  199.60        GOOG  1078.59

# %%
joined_stock_data = joined_stock_data.drop(columns=["Symbol aapl"])
joined_stock_data = joined_stock_data.drop(columns=["Symbol cost"])
joined_stock_data = joined_stock_data.drop(columns=["Symbol goog"])

joined_stock_data.head()
# Out:
#               AAPL    COST     GOOG
# Trade DATE
# 2018-05-11  188.59  195.76  1098.26
# 2018-05-14  188.15  195.88  1100.20
# 2018-05-15  186.44  195.48  1079.23
# 2018-05-16  188.18  198.71  1081.77
# 2018-05-17  186.99  199.60  1078.59

# %%
# Calculate the daily return using the 'pct_change()' function
joined_stock_data_returns = joined_stock_data.pct_change()
joined_stock_data_returns.head()
# Out:
#                 AAPL      COST      GOOG
# Trade DATE
# 2018-05-11       NaN       NaN       NaN
# 2018-05-14 -0.002333  0.000613  0.001766
# 2018-05-15 -0.009088 -0.002042 -0.019060
# 2018-05-16  0.009333  0.016523  0.002354
# 2018-05-17 -0.006324  0.004479 -0.002940

# %%
# Drop NAs
joined_stock_data_returns = joined_stock_data_returns.dropna().copy()
joined_stock_data_returns
# Out:
#                 AAPL      COST      GOOG
# Trade DATE
# 2018-05-14 -0.002333  0.000613  0.001766
# 2018-05-15 -0.009088 -0.002042 -0.019060
# 2018-05-16  0.009333  0.016523  0.002354
# 2018-05-17 -0.006324  0.004479 -0.002940
# 2018-05-18 -0.003637 -0.003206 -0.011339
# ...              ...       ...       ...
# 2019-05-03  0.012431  0.007953  0.019602
# 2019-05-06 -0.015443 -0.001594  0.003366
# 2019-05-07 -0.026957 -0.016583 -0.012855
# 2019-05-08  0.000197  0.004830 -0.006669
# 2019-05-09 -0.010744  0.008826 -0.003335
#
# [249 rows x 3 columns]

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
portfolio_return = joined_stock_data_returns.dot(weights)


joined_data_all.head()
# Display sample data
portfolio_return.head()
# Out:
# Trade DATE
# 2018-05-14    0.000015
# 2018-05-15   -0.010064
# 2018-05-16    0.009403
# 2018-05-17   -0.001595
# 2018-05-18   -0.006061
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
#portfolio_return how to add a colum name fpr the custom port+
joined_data_cols["custom"]=portfolio_return
joined_data_cols. tail()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2019-04-15                  -0.001422           -0.001156
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2019-04-15                     0.000398               -0.010492 -0.004331
# 2019-04-16                    -0.000831                0.000837 -0.006945
# 2019-04-17                    -0.004409                0.003222 -0.010301
# 2019-04-18                     0.000582                0.001916 -0.000588
# 2019-04-22                    -0.003640               -0.001088  0.000677
#
#               Algo 2     SP500    custom
# Date
# 2019-04-15 -0.004572 -0.000509  0.007522
# 2019-04-16  0.002899  0.002279  0.000340
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
joined_data_all = joined_data_cols.dropna().copy()
joined_data_all
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2018-05-14                   0.000000            0.000000
# 2018-05-15                  -0.000726           -0.001409
# 2018-05-16                   0.008637            0.006244
# 2018-05-17                  -0.001955            0.002524
# 2018-05-18                  -0.004357           -0.002672
# ...                               ...                 ...
# 2019-04-15                  -0.001422           -0.001156
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2018-05-14                     0.000000                0.000000  0.000915
# 2018-05-15                    -0.003189               -0.014606 -0.001135
# ...

# %%
#Checking nulls
joined_data_all.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# Algo 1                         0
# Algo 2                         0
# SP500                          0
# custom                         0
# dtype: int64

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
daily_std_custom = portfolio_return.std()
portfolio_return
# Out:
# Trade DATE
# 2018-05-14    0.000015
# 2018-05-15   -0.010064
# 2018-05-16    0.009403
# 2018-05-17   -0.001595
# 2018-05-18   -0.006061
#                 ...
# 2019-05-03    0.013329
# 2019-05-06   -0.004557
# 2019-05-07   -0.018798
# 2019-05-08   -0.000547
# 2019-05-09   -0.001751
# Length: 249, dtype: float64

# %%
# Calculate the annualized `std`
annualized_std_custom = daily_std_custom*np.sqrt(252)
annualized_std_custom
# Out:
# 0.2102620573198797

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
portfolio_return_std21 = portfolio_return.rolling(window=21).std()
portfolio_return_std21

# Plot rolling standard deviation
 # Set figure of the daily closing prices of NFLX
ax = portfolio_return_std21.plot(figsize=(15,5))

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
correlation_join_custom = joined_stock_data_returns.corr()
correlation_join_custom

#plot the correlation
sns.heatmap(correlation_join_custom, vmin=-1, vmax=1, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
# Calculate covariance of a single portfolio (Algo Portfolio)
custom_covariance = joined_data_all['custom'].cov(joined_data_all['SP500'])

# %%
# Computing beta
custom_beta = custom_covariance / variance_sp500

print(f"custom portfolio: {custom_beta}")
# Out:
# custom portfolio: 0.009730527678248398

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
sharpe_ratios_custom = (joined_data_all.mean() * 252) / (joined_data_all.std() * np.sqrt(252))
sharpe_ratios_custom.sort_values(inplace=True)
sharpe_ratios_custom
# Out:
# TIGER GLOBAL MANAGEMENT LLC   -1.066635
# SP500                         -0.427676
# Algo 2                         0.007334
# BERKSHIRE HATHAWAY INC         0.103006
# PAULSON & CO.INC.              0.227577
# SOROS FUND MANAGEMENT LLC      0.380007
# custom                         0.876152
# Algo 1                         2.001260
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios_custom.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ### How does your portfolio do?
#
#  My Custom portfolio did not outperform the SP500 or most of the other Portfolios for the time period the custom stock data was available.
